# %% [markdown]
# # pre-processing

# %%
dic = {'곡류군': 0, '과일군': 1, '고지방 어육류군': 2, '중지방 어육류군': 3, '저지방 어육류군': 4, '우유군': 5, '저지방 우유군': 6,\
       '지방군': 7, '채소군': 8}

# %%
f = open("D:/Backup_data/jongkeun/Kangwon/samples/sample.csv", 'r', encoding='UTF8')
data = f.readlines()

# %% [markdown]
# # import

# %%
import time
import numpy as np
import tensorflow as tf
# warning 보이지 않게 설정
tf.logging.set_verbosity(tf.logging.ERROR)

# %% [markdown]
# # hyper parameter
# - training_epochs: 학습 에폭, 1,000번 반복 학습하도록 설정
# - batch_size: 배치 크기, 한 번에 20개의 데이터를 학습하도록 설정
# - width: input의 가로 길이, 3
# - height: input의 세로 길이, 1
# - initial_rate: 초기 학습률, 0.0001
# - label_len: 분류 레이블 크기(총 식품군의 종류), 9

# %%
training_epochs = 1000
batch_size = 20
width = 3
height = 1
initial_rate = 1e-3
label_len = 9

# %% [markdown]
# # dataset
#
# - 탄수화물, 단백질, 지방 데이터를 정규화하여 배열로 저장 (shape=[1,3])
# - 식품군에 따라 레이블 원핫으로 정의 (0~9)

# %%
_input = []
_label = []
label = '000000000'

"""
- csv 포맷으로 정의한 data를 line별로 읽어와 각 line을 [식품군, 탄수화물, 단백질, 지방]의 형태로 변환

 _class: 식품군
kcal: 에너지
carbo: 탄수화물
protein: 단백질
fat: 지방

- 탄수화물, 단백질, 지방 함량을 정규화 (세 가지의 총 합이 1이 되도록)

"""

for idx, line in enumerate(data) :
    
    info = line.split(',')
    
    _class = info[0]
    kcal = float(info[1])
    carbo = float(info[2])
    protein = float(info[3])
    fat = float(info[4][:-1])
    
    val = carbo+protein+fat
    _input.append([carbo/val, protein/val, fat/val])
    _label.append(list(label[:dic[_class]]+'1'+label[dic[_class]+1:]))

# %%
"""
- 정규화한 데이터를 합성곱 신경망에 맞게 shape 변환 => (총 데이터 수, 높이, 너비, 1)
- input으로 들어갈 땐, (1, 높이, 너비, 1)의 형태로 입력

- label 데이터도 위와 같은 포맷으로 변환 => (총 데이터 수, 레이블 길이(9))

"""

_input = np.reshape(_input, [-1, height*width])
_input = np.array(np.reshape(_input, [-1, height, width, 1]), dtype=np.float32)

_label = np.array(np.reshape(_label, [-1, label_len]), dtype=np.int32)

# %% [markdown]
# # feeding value
# - 학습에 필요한 value 정의
# - x: input data([탄수화물, 단백질, 지방])
# - y_: label (식품군)
# - lr: 학습률
# - is_training (training과 evaluation 구분을 위한 boolean 값)

# %%
x = tf.placeholder(dtype=tf.float32, shape=[None, height, width, 1])
y_ = tf.placeholder(dtype=tf.float32, shape=[None, label_len])
lr = tf.placeholder(dtype=tf.float32)
is_training = tf.placeholder(dtype=tf.bool)

# %% [markdown]
# # layers
# - 합성곱 신경망 구현한 부분
# - 3개의 합성곱 계층과, 1개의 max pooling 계층, 1개의 FC 계층으로 구현(깊이와 구조는 임의로 설정)
# - 활성화 함수는 ReLU를 사용
# - dropout은 합성곱 계층에서 0.7, FC 계층에서 0.5로 설정
# - 분류기는 softmax 사용
# - optimizer는 Adam 사용

# %%
layer1 = tf.layers.conv2d(inputs=x, filters=8, kernel_size=[3,3], padding='SAME')
layer2 = tf.layers.conv2d(layer1, 128, [3,3], padding='SAME')
layer3 = tf.layers.conv2d(layer2, 128, [3,3], padding='SAME')
layer_ = tf.layers.max_pooling2d(inputs=layer3, pool_size=[3,3], strides=[1,1], padding='SAME')
layer_ = tf.layers.dropout(inputs=layer_, rate=0.7, training=is_training)

fc = tf.contrib.layers.flatten(inputs=layer_)
fc = tf.layers.dense(inputs=fc, units=256, activation=tf.nn.relu)
fc = tf.layers.dropout(fc, 0.5, is_training)

logits = tf.layers.dense(fc, label_len, activation=None)
pred = tf.nn.softmax(logits)
# reduce_mean: 배열 전체 원소의 합을 원소 개수로 나누어 계산
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=y_))
train = tf.train.AdamOptimizer(lr).minimize(loss)
correct = tf.equal(tf.argmax(pred, 1), tf.argmax(y_, 1))
acc = tf.reduce_mean(tf.cast(correct, tf.float32))
label_output = tf.argmax(pred, 1)
label_input = tf.argmax(y_, 1)

# %% [markdown]
# # session

# %%
config = tf.ConfigProto(log_device_placement = True)
config.gpu_options.allow_growth = True

with tf.Session(config=config) as sess :
    coord = tf.train.Coordinator()
    thread = tf.train.start_queue_runners(sess=sess, coord=coord)
    
    sess.run(tf.global_variables_initializer())
    
    total_batch = int(len(_input) / batch_size)
    correct_list = []
    incorrect_list = []
    cost_list = []
    cost_sum_list = []
    
    total_acc = 0
    cost_sum = 0
    cost_flag = 0
    
    start_time = time.time()
    
    print("")
    
    for epoch in range(training_epochs) :
        total_cost = 0
                
        if epoch%10 == 9 :
            midpoint = int(time.time() - start_time)
        
            print("")
            print("=======================================================================================")
            print('{:03d}:{:02d}:{:02d}'.format(midpoint//3600, (midpoint%3600//60), midpoint%60))
            print("=======================================================================================")
            print("")
        
        batch_index = np.random.choice(len(_input), total_batch, replace=False)
                
        for i in range(total_batch) :                
            _, _loss = sess.run([train, loss], feed_dict={x: [_input[batch_index[i]]], y_: [_label[batch_index[i]]], 
                                                          is_training: True, lr: initial_rate})
            
            total_cost += _loss

        avg_cost = total_cost/total_batch
        print('Epoch : ', '%4d' % (epoch + 1), '    Avg. cost = ', '{:.4f}'.format(avg_cost))            
        
#         train_writer.add_summary(_merge, epoch)
               
    print("")
    print("=======================================================================================")
    print("================================     Training done     ================================")
    print("=======================================================================================")
    print("")
    
    for test in range(len(_input)) :
        _acc, _label_input, _label_output = sess.run([acc, label_input, label_output], 
                             feed_dict={x: [_input[test]], y_: [_label[test]], is_training: False})

        total_acc += _acc
        
        print("n: ", test, "    label_input: ", _label_input, "    label_output: ", _label_output)
        
        if _label_input == _label_output :
            correct_list.append(test)   
        else :
            incorrect_list.append(test)
        
    print("")
    print("          TOTAL ACC    : ", '{:.5f}'.format(total_acc / len(_input)))
    print("")
    
    end_time = int(time.time() - start_time)
    
    print("")
    print("=======================================================================================")
    print('{:03d}:{:02d}:{:02d}'.format(end_time//3600, (end_time%3600//60), end_time%60))
    print("=======================================================================================")
    print("")
    
    coord.request_stop()
    coord.join(thread)
# Out:
# Epoch :     1     Avg. cost =  2.1813
# Epoch :     2     Avg. cost =  1.9025
# Epoch :     3     Avg. cost =  1.8159
# Epoch :     4     Avg. cost =  1.3705
# Epoch :     5     Avg. cost =  1.0244
# Epoch :     6     Avg. cost =  0.9940
# Epoch :     7     Avg. cost =  1.2223
# Epoch :     8     Avg. cost =  1.1413
# Epoch :     9     Avg. cost =  1.1780
#
# =======================================================================================
# 000:00:02
# =======================================================================================
#
# Epoch :    10     Avg. cost =  1.0796
# Epoch :    11     Avg. cost =  1.1959
# Epoch :    12     Avg. cost =  1.4928
# Epoch :    13     Avg. cost =  1.1390
# Epoch :    14     Avg. cost =  1.3150
# Epoch :    15     Avg. cost =  1.4345
# Epoch :    16     Avg. cost =  0.9296
# Epoch :    17     Avg. cost =  1.3454
# Epoch :    18     Avg. cost =  1.1265
# Epoch :    19     Avg. cost =  0.9800
#
# =======================================================================================
# 000:00:03
# =======================================================================================
#
# Epoch :    20     Avg. cost =  0.9736
# Epoch :    21     Avg. cost =  0.7681
# Epoch :    22     Avg. cost =  0.6811
# Epoch :    23     Avg. cost =  0.7230
# Epoch :    24     Avg. cost =  1.1931
# Epoch :    25     Avg. cost =  0.8663
# Epoch :    26     Avg. cost =  1.3163
# Epoch :    27     Avg. cost =  1.3872
# Epoch :    28     Avg. cost =  0.7545
# Epoch :    29     Avg. cost =  0.8461
#
# =======================================================================================
# 000:00:03
# =======================================================================================
#
# Epoch :    30     Avg. cost =  1.1936
# Epoch :    31     Avg. cost =  0.8891
# Epoch :    32     Avg. cost =  1.0710
# Epoch :    33     Avg. cost =  1.4231
# Epoch :    34     Avg. cost =  0.9549
# Epoch :    35     Avg. cost =  1.1403
# Epoch :    36     Avg. cost =  0.9163
# Epoch :    37     Avg. cost =  0.8652
# Epoch :    38     Avg. cost =  1.1086
# Epoch :    39     Avg. cost =  0.8206
#
# =======================================================================================
# 000:00:04
# =======================================================================================
#
# Epoch :    40     Avg. cost =  1.0931
# Epoch :    41     Avg. cost =  0.7749
# Epoch :    42     Avg. cost =  0.4996
# Epoch :    43     Avg. cost =  0.8403
# Epoch :    44     Avg. cost =  1.0185
# Epoch :    45     Avg. cost =  0.8289
# Epoch :    46     Avg. cost =  0.7917
# Epoch :    47     Avg. cost =  0.6686
# Epoch :    48     Avg. cost =  0.5672
# Epoch :    49     Avg. cost =  0.5118
#
# =======================================================================================
# 000:00:04
# =======================================================================================
#
# Epoch :    50     Avg. cost =  0.7550
# Epoch :    51     Avg. cost =  0.7857
# Epoch :    52     Avg. cost =  0.7029
# Epoch :    53     Avg. cost =  0.5739
# Epoch :    54     Avg. cost =  1.4971
# Epoch :    55     Avg. cost =  1.7966
# Epoch :    56     Avg. cost =  1.0641
# Epoch :    57     Avg. cost =  0.6111
# Epoch :    58     Avg. cost =  0.8798
# Epoch :    59     Avg. cost =  0.7563
#
# =======================================================================================
# 000:00:04
# =======================================================================================
#
# Epoch :    60     Avg. cost =  1.3882
# Epoch :    61     Avg. cost =  0.7301
# Epoch :    62     Avg. cost =  0.7348
# Epoch :    63     Avg. cost =  0.9319
# Epoch :    64     Avg. cost =  0.8212
# Epoch :    65     Avg. cost =  0.7169
# Epoch :    66     Avg. cost =  1.1331
# Epoch :    67     Avg. cost =  0.8663
# Epoch :    68     Avg. cost =  0.9081
# Epoch :    69     Avg. cost =  0.8313
#
# =======================================================================================
# 000:00:05
# =======================================================================================
#
# Epoch :    70     Avg. cost =  0.6655
# Epoch :    71     Avg. cost =  0.9336
# Epoch :    72     Avg. cost =  1.2480
# Epoch :    73     Avg. cost =  0.6240
# Epoch :    74     Avg. cost =  0.6711
# Epoch :    75     Avg. cost =  0.5453
# Epoch :    76     Avg. cost =  0.9277
# Epoch :    77     Avg. cost =  1.1005
# Epoch :    78     Avg. cost =  0.6432
# Epoch :    79     Avg. cost =  0.7213
#
# =======================================================================================
# 000:00:05
# =======================================================================================
#
# Epoch :    80     Avg. cost =  0.5704
# Epoch :    81     Avg. cost =  0.4881
# Epoch :    82     Avg. cost =  0.4792
# Epoch :    83     Avg. cost =  1.1002
# Epoch :    84     Avg. cost =  0.8668
# Epoch :    85     Avg. cost =  1.0483
# Epoch :    86     Avg. cost =  0.6947
# Epoch :    87     Avg. cost =  0.8717
# Epoch :    88     Avg. cost =  1.1157
# Epoch :    89     Avg. cost =  0.4911
#
# =======================================================================================
# 000:00:06
# =======================================================================================
#
# Epoch :    90     Avg. cost =  1.0315
# Epoch :    91     Avg. cost =  1.0522
# Epoch :    92     Avg. cost =  1.2016
# Epoch :    93     Avg. cost =  0.9549
# Epoch :    94     Avg. cost =  0.8160
# Epoch :    95     Avg. cost =  0.7263
# Epoch :    96     Avg. cost =  0.6754
# Epoch :    97     Avg. cost =  0.8105
# Epoch :    98     Avg. cost =  0.9020
# Epoch :    99     Avg. cost =  0.9907
#
# =======================================================================================
# 000:00:06
# =======================================================================================
#
# Epoch :   100     Avg. cost =  0.7316
# Epoch :   101     Avg. cost =  0.6717
# Epoch :   102     Avg. cost =  1.1157
# Epoch :   103     Avg. cost =  0.5232
# Epoch :   104     Avg. cost =  0.4109
# Epoch :   105     Avg. cost =  0.9807
# Epoch :   106     Avg. cost =  0.7347
# Epoch :   107     Avg. cost =  0.6741
# Epoch :   108     Avg. cost =  0.6846
# Epoch :   109     Avg. cost =  0.6176
#
# =======================================================================================
# 000:00:06
# =======================================================================================
#
# Epoch :   110     Avg. cost =  1.2401
# Epoch :   111     Avg. cost =  0.5073
# Epoch :   112     Avg. cost =  0.7027
# Epoch :   113     Avg. cost =  0.5298
# Epoch :   114     Avg. cost =  1.0636
# Epoch :   115     Avg. cost =  0.8301
# Epoch :   116     Avg. cost =  0.9182
# Epoch :   117     Avg. cost =  0.7321
# Epoch :   118     Avg. cost =  0.7853
# Epoch :   119     Avg. cost =  0.7834
#
# =======================================================================================
# 000:00:07
# =======================================================================================
#
# Epoch :   120     Avg. cost =  0.8405
# Epoch :   121     Avg. cost =  0.5889
# Epoch :   122     Avg. cost =  0.5581
# Epoch :   123     Avg. cost =  0.6905
# Epoch :   124     Avg. cost =  0.7450
# Epoch :   125     Avg. cost =  0.6185
# Epoch :   126     Avg. cost =  1.0295
# Epoch :   127     Avg. cost =  0.6482
# Epoch :   128     Avg. cost =  0.9787
# Epoch :   129     Avg. cost =  1.1103
#
# =======================================================================================
# 000:00:07
# =======================================================================================
#
# Epoch :   130     Avg. cost =  0.9508
# Epoch :   131     Avg. cost =  0.7894
# Epoch :   132     Avg. cost =  0.5163
# Epoch :   133     Avg. cost =  1.1543
# Epoch :   134     Avg. cost =  1.0213
# Epoch :   135     Avg. cost =  0.8013
# Epoch :   136     Avg. cost =  0.9320
# Epoch :   137     Avg. cost =  0.7932
# Epoch :   138     Avg. cost =  0.5015
# Epoch :   139     Avg. cost =  0.4643
#
# =======================================================================================
# 000:00:07
# =======================================================================================
#
# Epoch :   140     Avg. cost =  0.6590
# Epoch :   141     Avg. cost =  0.8279
# Epoch :   142     Avg. cost =  0.6217
# Epoch :   143     Avg. cost =  1.1394
# Epoch :   144     Avg. cost =  0.6975
# Epoch :   145     Avg. cost =  1.2001
# Epoch :   146     Avg. cost =  0.8732
# Epoch :   147     Avg. cost =  0.7239
# Epoch :   148     Avg. cost =  1.2834
# Epoch :   149     Avg. cost =  0.8289
#
# =======================================================================================
# 000:00:08
# =======================================================================================
#
# Epoch :   150     Avg. cost =  1.0796
# Epoch :   151     Avg. cost =  0.8731
# Epoch :   152     Avg. cost =  0.8274
# Epoch :   153     Avg. cost =  0.7408
# Epoch :   154     Avg. cost =  0.7022
# Epoch :   155     Avg. cost =  0.7228
# Epoch :   156     Avg. cost =  0.9854
# Epoch :   157     Avg. cost =  0.7301
# Epoch :   158     Avg. cost =  0.7097
# Epoch :   159     Avg. cost =  1.1473
#
# =======================================================================================
# 000:00:08
# =======================================================================================
#
# Epoch :   160     Avg. cost =  0.6266
# Epoch :   161     Avg. cost =  0.6561
# Epoch :   162     Avg. cost =  0.8517
# Epoch :   163     Avg. cost =  0.5202
# Epoch :   164     Avg. cost =  0.7649
# Epoch :   165     Avg. cost =  0.7733
# Epoch :   166     Avg. cost =  0.6943
# Epoch :   167     Avg. cost =  0.8569
# Epoch :   168     Avg. cost =  0.7168
# Epoch :   169     Avg. cost =  0.8257
#
# =======================================================================================
# 000:00:09
# =======================================================================================
#
# Epoch :   170     Avg. cost =  0.7700
# Epoch :   171     Avg. cost =  0.8196
# Epoch :   172     Avg. cost =  0.4542
# Epoch :   173     Avg. cost =  0.7699
# Epoch :   174     Avg. cost =  0.7900
# Epoch :   175     Avg. cost =  0.4314
# Epoch :   176     Avg. cost =  1.2665
# Epoch :   177     Avg. cost =  0.6688
# Epoch :   178     Avg. cost =  0.4615
# Epoch :   179     Avg. cost =  1.1455
#
# =======================================================================================
# 000:00:09
# =======================================================================================
#
# Epoch :   180     Avg. cost =  0.7013
# Epoch :   181     Avg. cost =  1.0715
# Epoch :   182     Avg. cost =  0.4562
# Epoch :   183     Avg. cost =  0.8876
# Epoch :   184     Avg. cost =  0.5893
# Epoch :   185     Avg. cost =  1.0368
# Epoch :   186     Avg. cost =  0.8294
# Epoch :   187     Avg. cost =  0.9699
# Epoch :   188     Avg. cost =  0.4997
# Epoch :   189     Avg. cost =  0.7195
#
# =======================================================================================
# 000:00:09
# =======================================================================================
#
# Epoch :   190     Avg. cost =  0.7676
# Epoch :   191     Avg. cost =  0.9273
# Epoch :   192     Avg. cost =  0.8817
# Epoch :   193     Avg. cost =  0.7448
# Epoch :   194     Avg. cost =  0.9096
# Epoch :   195     Avg. cost =  0.6267
# Epoch :   196     Avg. cost =  0.5497
# Epoch :   197     Avg. cost =  1.1437
# Epoch :   198     Avg. cost =  0.8973
# Epoch :   199     Avg. cost =  0.9037
#
# =======================================================================================
# 000:00:10
# =======================================================================================
#
# Epoch :   200     Avg. cost =  0.6639
# Epoch :   201     Avg. cost =  0.5563
# Epoch :   202     Avg. cost =  1.0943
# Epoch :   203     Avg. cost =  1.1386
# Epoch :   204     Avg. cost =  0.7586
# Epoch :   205     Avg. cost =  0.8224
# Epoch :   206     Avg. cost =  0.6548
# Epoch :   207     Avg. cost =  0.3684
# Epoch :   208     Avg. cost =  0.7289
# Epoch :   209     Avg. cost =  0.5899
#
# =======================================================================================
# 000:00:10
# =======================================================================================
#
# Epoch :   210     Avg. cost =  0.6373
# Epoch :   211     Avg. cost =  1.0477
# Epoch :   212     Avg. cost =  0.3486
# Epoch :   213     Avg. cost =  0.4263
# Epoch :   214     Avg. cost =  0.6829
# Epoch :   215     Avg. cost =  0.8914
# Epoch :   216     Avg. cost =  0.6100
# Epoch :   217     Avg. cost =  0.6580
# Epoch :   218     Avg. cost =  0.7677
# Epoch :   219     Avg. cost =  1.2237
#
# =======================================================================================
# 000:00:10
# =======================================================================================
#
# Epoch :   220     Avg. cost =  1.0217
# Epoch :   221     Avg. cost =  0.6721
# Epoch :   222     Avg. cost =  0.8735
# Epoch :   223     Avg. cost =  0.4131
# Epoch :   224     Avg. cost =  0.8597
# Epoch :   225     Avg. cost =  0.8551
# Epoch :   226     Avg. cost =  0.6359
# Epoch :   227     Avg. cost =  1.0525
# Epoch :   228     Avg. cost =  0.7671
# Epoch :   229     Avg. cost =  0.5725
#
# =======================================================================================
# 000:00:11
# =======================================================================================
#
# Epoch :   230     Avg. cost =  0.9248
# Epoch :   231     Avg. cost =  0.5457
# Epoch :   232     Avg. cost =  0.7889
# Epoch :   233     Avg. cost =  0.3138
# Epoch :   234     Avg. cost =  0.6979
# Epoch :   235     Avg. cost =  0.8363
# Epoch :   236     Avg. cost =  1.2246
# Epoch :   237     Avg. cost =  0.6341
# Epoch :   238     Avg. cost =  0.6411
# Epoch :   239     Avg. cost =  0.9914
#
# =======================================================================================
# 000:00:11
# =======================================================================================
#
# Epoch :   240     Avg. cost =  1.0817
# Epoch :   241     Avg. cost =  0.6734
# Epoch :   242     Avg. cost =  0.8944
# Epoch :   243     Avg. cost =  1.3303
# Epoch :   244     Avg. cost =  0.3911
# Epoch :   245     Avg. cost =  0.5741
# Epoch :   246     Avg. cost =  0.9262
# Epoch :   247     Avg. cost =  0.6979
# Epoch :   248     Avg. cost =  0.4353
# Epoch :   249     Avg. cost =  0.4315
#
# =======================================================================================
# 000:00:11
# =======================================================================================
#
# Epoch :   250     Avg. cost =  0.8782
# Epoch :   251     Avg. cost =  0.9299
# Epoch :   252     Avg. cost =  0.7582
# Epoch :   253     Avg. cost =  0.7064
# Epoch :   254     Avg. cost =  0.9056
# Epoch :   255     Avg. cost =  0.7452
# Epoch :   256     Avg. cost =  0.7749
# Epoch :   257     Avg. cost =  0.6783
# Epoch :   258     Avg. cost =  1.0069
# Epoch :   259     Avg. cost =  0.8667
#
# =======================================================================================
# 000:00:12
# =======================================================================================
#
# Epoch :   260     Avg. cost =  0.5580
# Epoch :   261     Avg. cost =  1.2366
# Epoch :   262     Avg. cost =  0.7885
# Epoch :   263     Avg. cost =  0.9323
# Epoch :   264     Avg. cost =  0.8678
# Epoch :   265     Avg. cost =  0.8428
# Epoch :   266     Avg. cost =  1.1968
# Epoch :   267     Avg. cost =  0.6424
# Epoch :   268     Avg. cost =  0.6306
# Epoch :   269     Avg. cost =  0.8128
#
# =======================================================================================
# 000:00:12
# =======================================================================================
#
# Epoch :   270     Avg. cost =  0.6540
# Epoch :   271     Avg. cost =  0.4656
# Epoch :   272     Avg. cost =  1.0022
# Epoch :   273     Avg. cost =  0.7001
# Epoch :   274     Avg. cost =  0.5621
# Epoch :   275     Avg. cost =  1.0453
# Epoch :   276     Avg. cost =  0.6531
# Epoch :   277     Avg. cost =  1.4516
# Epoch :   278     Avg. cost =  0.5399
# Epoch :   279     Avg. cost =  0.6783
#
# =======================================================================================
# 000:00:13
# =======================================================================================
#
# Epoch :   280     Avg. cost =  0.7780
# Epoch :   281     Avg. cost =  0.4437
# Epoch :   282     Avg. cost =  0.6064
# Epoch :   283     Avg. cost =  0.7830
# Epoch :   284     Avg. cost =  0.6044
# Epoch :   285     Avg. cost =  0.6364
# Epoch :   286     Avg. cost =  0.8454
# Epoch :   287     Avg. cost =  0.7954
# Epoch :   288     Avg. cost =  0.5882
# Epoch :   289     Avg. cost =  0.9750
#
# =======================================================================================
# 000:00:13
# =======================================================================================
#
# Epoch :   290     Avg. cost =  0.6875
# Epoch :   291     Avg. cost =  0.8735
# Epoch :   292     Avg. cost =  1.0687
# Epoch :   293     Avg. cost =  0.4263
# Epoch :   294     Avg. cost =  1.1405
# Epoch :   295     Avg. cost =  0.6264
# Epoch :   296     Avg. cost =  0.8699
# Epoch :   297     Avg. cost =  0.7459
# Epoch :   298     Avg. cost =  0.7985
# Epoch :   299     Avg. cost =  0.5583
#
# =======================================================================================
# 000:00:14
# =======================================================================================
#
# Epoch :   300     Avg. cost =  0.8634
# Epoch :   301     Avg. cost =  0.7291
# Epoch :   302     Avg. cost =  0.4670
# Epoch :   303     Avg. cost =  0.8607
# Epoch :   304     Avg. cost =  0.8807
# Epoch :   305     Avg. cost =  0.7832
# Epoch :   306     Avg. cost =  0.9877
# Epoch :   307     Avg. cost =  0.6661
# Epoch :   308     Avg. cost =  0.2694
# Epoch :   309     Avg. cost =  0.3027
#
# =======================================================================================
# 000:00:14
# =======================================================================================
#
# Epoch :   310     Avg. cost =  1.1808
# Epoch :   311     Avg. cost =  0.3496
# Epoch :   312     Avg. cost =  1.2853
# Epoch :   313     Avg. cost =  0.8895
# Epoch :   314     Avg. cost =  1.1005
# Epoch :   315     Avg. cost =  0.7632
# Epoch :   316     Avg. cost =  0.5344
# Epoch :   317     Avg. cost =  0.5603
# Epoch :   318     Avg. cost =  0.9678
# Epoch :   319     Avg. cost =  0.6779
#
# =======================================================================================
# 000:00:14
# =======================================================================================
#
# Epoch :   320     Avg. cost =  0.9925
# Epoch :   321     Avg. cost =  0.6656
# Epoch :   322     Avg. cost =  0.2687
# Epoch :   323     Avg. cost =  0.4459
# Epoch :   324     Avg. cost =  0.4851
# Epoch :   325     Avg. cost =  0.9478
# Epoch :   326     Avg. cost =  0.3578
# Epoch :   327     Avg. cost =  0.7369
# Epoch :   328     Avg. cost =  0.6495
# Epoch :   329     Avg. cost =  0.5729
#
# =======================================================================================
# 000:00:15
# =======================================================================================
#
# Epoch :   330     Avg. cost =  0.6764
# Epoch :   331     Avg. cost =  0.7972
# Epoch :   332     Avg. cost =  0.5326
# Epoch :   333     Avg. cost =  0.9190
# Epoch :   334     Avg. cost =  0.4595
# Epoch :   335     Avg. cost =  0.3933
# Epoch :   336     Avg. cost =  0.4248
# Epoch :   337     Avg. cost =  0.8241
# Epoch :   338     Avg. cost =  1.0527
# Epoch :   339     Avg. cost =  0.6955
#
# =======================================================================================
# 000:00:15
# =======================================================================================
#
# Epoch :   340     Avg. cost =  0.3630
# Epoch :   341     Avg. cost =  0.9203
# Epoch :   342     Avg. cost =  1.0627
# Epoch :   343     Avg. cost =  0.7389
# Epoch :   344     Avg. cost =  0.7013
# Epoch :   345     Avg. cost =  0.8854
# Epoch :   346     Avg. cost =  1.0713
# Epoch :   347     Avg. cost =  1.0153
# Epoch :   348     Avg. cost =  1.0362
# Epoch :   349     Avg. cost =  0.7778
#
# =======================================================================================
# 000:00:15
# =======================================================================================
#
# Epoch :   350     Avg. cost =  0.9302
# Epoch :   351     Avg. cost =  0.5402
# Epoch :   352     Avg. cost =  0.9243
# Epoch :   353     Avg. cost =  0.6467
# Epoch :   354     Avg. cost =  1.0015
# Epoch :   355     Avg. cost =  1.1070
# Epoch :   356     Avg. cost =  0.8612
# Epoch :   357     Avg. cost =  0.7405
# Epoch :   358     Avg. cost =  0.7378
# Epoch :   359     Avg. cost =  0.4326
#
# =======================================================================================
# 000:00:16
# =======================================================================================
#
# Epoch :   360     Avg. cost =  0.5449
# Epoch :   361     Avg. cost =  0.5648
# Epoch :   362     Avg. cost =  1.2361
# Epoch :   363     Avg. cost =  0.6168
# Epoch :   364     Avg. cost =  0.7070
# Epoch :   365     Avg. cost =  0.6860
# Epoch :   366     Avg. cost =  0.6232
# Epoch :   367     Avg. cost =  0.3007
# Epoch :   368     Avg. cost =  0.4120
# Epoch :   369     Avg. cost =  0.8092
#
# =======================================================================================
# 000:00:16
# =======================================================================================
#
# Epoch :   370     Avg. cost =  0.6486
# Epoch :   371     Avg. cost =  0.7561
# Epoch :   372     Avg. cost =  1.1674
# Epoch :   373     Avg. cost =  0.4464
# Epoch :   374     Avg. cost =  0.8767
# Epoch :   375     Avg. cost =  1.2564
# Epoch :   376     Avg. cost =  0.7497
# Epoch :   377     Avg. cost =  0.7709
# Epoch :   378     Avg. cost =  0.5811
# Epoch :   379     Avg. cost =  0.7944
#
# =======================================================================================
# 000:00:17
# =======================================================================================
#
# Epoch :   380     Avg. cost =  0.6006
# Epoch :   381     Avg. cost =  1.2242
# Epoch :   382     Avg. cost =  0.5999
# Epoch :   383     Avg. cost =  1.2018
# Epoch :   384     Avg. cost =  0.7299
# Epoch :   385     Avg. cost =  0.3950
# Epoch :   386     Avg. cost =  0.8774
# Epoch :   387     Avg. cost =  1.0845
# Epoch :   388     Avg. cost =  0.6182
# Epoch :   389     Avg. cost =  0.7428
#
# =======================================================================================
# 000:00:17
# =======================================================================================
#
# Epoch :   390     Avg. cost =  0.6959
# Epoch :   391     Avg. cost =  0.5790
# Epoch :   392     Avg. cost =  0.6652
# Epoch :   393     Avg. cost =  1.0981
# Epoch :   394     Avg. cost =  0.5545
# Epoch :   395     Avg. cost =  0.8979
# Epoch :   396     Avg. cost =  0.4461
# Epoch :   397     Avg. cost =  1.0655
# Epoch :   398     Avg. cost =  0.5824
# Epoch :   399     Avg. cost =  0.8121
#
# =======================================================================================
# 000:00:17
# =======================================================================================
#
# Epoch :   400     Avg. cost =  0.9393
# Epoch :   401     Avg. cost =  0.5636
# Epoch :   402     Avg. cost =  0.8176
# Epoch :   403     Avg. cost =  0.4768
# Epoch :   404     Avg. cost =  1.0527
# Epoch :   405     Avg. cost =  0.5074
# Epoch :   406     Avg. cost =  0.6053
# Epoch :   407     Avg. cost =  1.3683
# Epoch :   408     Avg. cost =  0.7224
# Epoch :   409     Avg. cost =  0.9539
#
# =======================================================================================
# 000:00:18
# =======================================================================================
#
# Epoch :   410     Avg. cost =  0.8535
# Epoch :   411     Avg. cost =  0.7393
# Epoch :   412     Avg. cost =  0.6942
# Epoch :   413     Avg. cost =  0.6007
# Epoch :   414     Avg. cost =  0.4542
# Epoch :   415     Avg. cost =  0.7841
# Epoch :   416     Avg. cost =  0.9320
# Epoch :   417     Avg. cost =  0.9807
# Epoch :   418     Avg. cost =  0.9429
# Epoch :   419     Avg. cost =  0.5747
#
# =======================================================================================
# 000:00:18
# =======================================================================================
#
# Epoch :   420     Avg. cost =  1.0612
# Epoch :   421     Avg. cost =  0.9472
# Epoch :   422     Avg. cost =  0.5898
# Epoch :   423     Avg. cost =  0.5411
# Epoch :   424     Avg. cost =  0.7012
# Epoch :   425     Avg. cost =  1.0863
# Epoch :   426     Avg. cost =  1.1780
# Epoch :   427     Avg. cost =  0.5047
# Epoch :   428     Avg. cost =  0.8019
# Epoch :   429     Avg. cost =  0.4794
#
# =======================================================================================
# 000:00:18
# =======================================================================================
#
# Epoch :   430     Avg. cost =  0.9872
# Epoch :   431     Avg. cost =  0.5486
# Epoch :   432     Avg. cost =  0.7700
# Epoch :   433     Avg. cost =  1.0419
# Epoch :   434     Avg. cost =  0.6433
# Epoch :   435     Avg. cost =  1.1573
# Epoch :   436     Avg. cost =  0.7800
# Epoch :   437     Avg. cost =  0.8584
# Epoch :   438     Avg. cost =  0.8468
# Epoch :   439     Avg. cost =  0.7107
#
# =======================================================================================
# 000:00:19
# =======================================================================================
#
# Epoch :   440     Avg. cost =  0.5352
# Epoch :   441     Avg. cost =  0.7921
# Epoch :   442     Avg. cost =  0.5441
# Epoch :   443     Avg. cost =  0.5701
# Epoch :   444     Avg. cost =  0.5185
# Epoch :   445     Avg. cost =  0.8597
# Epoch :   446     Avg. cost =  0.7210
# Epoch :   447     Avg. cost =  0.7060
# Epoch :   448     Avg. cost =  0.8377
# Epoch :   449     Avg. cost =  0.5756
#
# =======================================================================================
# 000:00:19
# =======================================================================================
#
# Epoch :   450     Avg. cost =  0.5809
# Epoch :   451     Avg. cost =  0.9853
# Epoch :   452     Avg. cost =  0.5567
# Epoch :   453     Avg. cost =  1.0052
# Epoch :   454     Avg. cost =  0.7191
# Epoch :   455     Avg. cost =  0.4601
# Epoch :   456     Avg. cost =  0.3354
# Epoch :   457     Avg. cost =  0.6059
# Epoch :   458     Avg. cost =  0.9174
# Epoch :   459     Avg. cost =  0.4886
#
# =======================================================================================
# 000:00:20
# =======================================================================================
#
# Epoch :   460     Avg. cost =  0.5468
# Epoch :   461     Avg. cost =  1.0928
# Epoch :   462     Avg. cost =  0.4310
# Epoch :   463     Avg. cost =  0.5727
# Epoch :   464     Avg. cost =  1.0541
# Epoch :   465     Avg. cost =  0.7952
# Epoch :   466     Avg. cost =  0.5921
# Epoch :   467     Avg. cost =  1.2524
# Epoch :   468     Avg. cost =  1.0714
# Epoch :   469     Avg. cost =  0.5643
#
# =======================================================================================
# 000:00:20
# =======================================================================================
#
# Epoch :   470     Avg. cost =  0.8813
# Epoch :   471     Avg. cost =  0.5789
# Epoch :   472     Avg. cost =  0.5504
# Epoch :   473     Avg. cost =  0.7330
# Epoch :   474     Avg. cost =  0.6959
# Epoch :   475     Avg. cost =  0.8757
# Epoch :   476     Avg. cost =  1.2457
# Epoch :   477     Avg. cost =  0.3134
# Epoch :   478     Avg. cost =  0.6313
# Epoch :   479     Avg. cost =  0.5428
#
# =======================================================================================
# 000:00:20
# =======================================================================================
#
# Epoch :   480     Avg. cost =  0.5665
# Epoch :   481     Avg. cost =  0.6611
# Epoch :   482     Avg. cost =  0.7710
# Epoch :   483     Avg. cost =  0.6364
# Epoch :   484     Avg. cost =  1.0609
# Epoch :   485     Avg. cost =  0.7461
# Epoch :   486     Avg. cost =  0.4516
# Epoch :   487     Avg. cost =  1.0527
# Epoch :   488     Avg. cost =  0.5659
# Epoch :   489     Avg. cost =  0.8027
#
# =======================================================================================
# 000:00:21
# =======================================================================================
#
# Epoch :   490     Avg. cost =  0.7739
# Epoch :   491     Avg. cost =  0.8040
# Epoch :   492     Avg. cost =  0.4737
# Epoch :   493     Avg. cost =  0.9226
# Epoch :   494     Avg. cost =  0.7766
# Epoch :   495     Avg. cost =  0.7209
# Epoch :   496     Avg. cost =  0.5332
# Epoch :   497     Avg. cost =  0.6983
# Epoch :   498     Avg. cost =  0.6258
# Epoch :   499     Avg. cost =  0.6724
#
# =======================================================================================
# 000:00:21
# =======================================================================================
#
# Epoch :   500     Avg. cost =  0.6758
# Epoch :   501     Avg. cost =  1.2370
# Epoch :   502     Avg. cost =  1.0849
# Epoch :   503     Avg. cost =  0.8029
# Epoch :   504     Avg. cost =  0.7884
# Epoch :   505     Avg. cost =  0.6129
# Epoch :   506     Avg. cost =  0.7804
# Epoch :   507     Avg. cost =  0.5958
# Epoch :   508     Avg. cost =  0.4347
# Epoch :   509     Avg. cost =  0.7761
#
# =======================================================================================
# 000:00:21
# =======================================================================================
#
# Epoch :   510     Avg. cost =  0.7421
# Epoch :   511     Avg. cost =  0.5715
# Epoch :   512     Avg. cost =  0.5218
# Epoch :   513     Avg. cost =  0.8947
# Epoch :   514     Avg. cost =  0.4989
# Epoch :   515     Avg. cost =  1.0619
# Epoch :   516     Avg. cost =  1.3290
# Epoch :   517     Avg. cost =  0.9017
# Epoch :   518     Avg. cost =  0.8071
# Epoch :   519     Avg. cost =  0.9551
#
# =======================================================================================
# 000:00:22
# =======================================================================================
#
# Epoch :   520     Avg. cost =  0.6982
# Epoch :   521     Avg. cost =  0.4987
# Epoch :   522     Avg. cost =  0.5317
# Epoch :   523     Avg. cost =  0.8871
# Epoch :   524     Avg. cost =  0.7193
# Epoch :   525     Avg. cost =  0.7618
# Epoch :   526     Avg. cost =  0.7063
# Epoch :   527     Avg. cost =  0.5789
# Epoch :   528     Avg. cost =  0.4640
# Epoch :   529     Avg. cost =  1.1985
#
# =======================================================================================
# 000:00:22
# =======================================================================================
#
# Epoch :   530     Avg. cost =  0.6223
# Epoch :   531     Avg. cost =  0.6549
# Epoch :   532     Avg. cost =  0.9453
# Epoch :   533     Avg. cost =  0.5723
# Epoch :   534     Avg. cost =  0.7138
# Epoch :   535     Avg. cost =  0.9598
# Epoch :   536     Avg. cost =  0.5973
# Epoch :   537     Avg. cost =  0.4318
# Epoch :   538     Avg. cost =  0.4277
# Epoch :   539     Avg. cost =  0.6035
#
# =======================================================================================
# 000:00:23
# =======================================================================================
#
# Epoch :   540     Avg. cost =  0.6390
# Epoch :   541     Avg. cost =  0.5550
# Epoch :   542     Avg. cost =  0.9261
# Epoch :   543     Avg. cost =  0.8699
# Epoch :   544     Avg. cost =  0.7500
# Epoch :   545     Avg. cost =  0.4780
# Epoch :   546     Avg. cost =  0.7233
# Epoch :   547     Avg. cost =  0.9042
# Epoch :   548     Avg. cost =  0.3235
# Epoch :   549     Avg. cost =  0.9613
#
# =======================================================================================
# 000:00:23
# =======================================================================================
#
# Epoch :   550     Avg. cost =  0.5489
# Epoch :   551     Avg. cost =  1.3999
# Epoch :   552     Avg. cost =  1.3079
# Epoch :   553     Avg. cost =  1.0616
# Epoch :   554     Avg. cost =  0.6909
# Epoch :   555     Avg. cost =  0.5583
# Epoch :   556     Avg. cost =  0.8148
# Epoch :   557     Avg. cost =  1.1490
# Epoch :   558     Avg. cost =  0.8109
# Epoch :   559     Avg. cost =  0.4916
#
# =======================================================================================
# 000:00:23
# =======================================================================================
#
# Epoch :   560     Avg. cost =  0.9939
# Epoch :   561     Avg. cost =  0.7634
# Epoch :   562     Avg. cost =  0.8999
# Epoch :   563     Avg. cost =  0.7369
# Epoch :   564     Avg. cost =  0.5486
# Epoch :   565     Avg. cost =  0.9760
# Epoch :   566     Avg. cost =  0.9362
# Epoch :   567     Avg. cost =  0.5772
# Epoch :   568     Avg. cost =  0.9085
# Epoch :   569     Avg. cost =  0.7013
#
# =======================================================================================
# 000:00:24
# =======================================================================================
#
# Epoch :   570     Avg. cost =  0.5755
# Epoch :   571     Avg. cost =  0.5561
# Epoch :   572     Avg. cost =  0.6078
# Epoch :   573     Avg. cost =  0.5812
# Epoch :   574     Avg. cost =  0.6839
# Epoch :   575     Avg. cost =  0.8411
# Epoch :   576     Avg. cost =  0.8513
# Epoch :   577     Avg. cost =  0.4607
# Epoch :   578     Avg. cost =  0.7351
# Epoch :   579     Avg. cost =  0.6797
#
# =======================================================================================
# 000:00:24
# =======================================================================================
#
# Epoch :   580     Avg. cost =  1.0814
# Epoch :   581     Avg. cost =  0.3784
# Epoch :   582     Avg. cost =  0.9071
# Epoch :   583     Avg. cost =  0.4369
# Epoch :   584     Avg. cost =  0.3692
# Epoch :   585     Avg. cost =  0.7229
# Epoch :   586     Avg. cost =  0.5514
# Epoch :   587     Avg. cost =  0.5189
# Epoch :   588     Avg. cost =  0.5085
# Epoch :   589     Avg. cost =  0.5961
#
# =======================================================================================
# 000:00:24
# =======================================================================================
# Epoch :   590     Avg. cost =  0.7745
# Epoch :   591     Avg. cost =  0.3775
# Epoch :   592     Avg. cost =  0.9310
# Epoch :   593     Avg. cost =  0.7997
# Epoch :   594     Avg. cost =  1.0268
# Epoch :   595     Avg. cost =  0.8324
# Epoch :   596     Avg. cost =  1.1260
# Epoch :   597     Avg. cost =  0.9134
# Epoch :   598     Avg. cost =  0.3937
# Epoch :   599     Avg. cost =  0.7841
#
# =======================================================================================
# 000:00:25
# =======================================================================================
#
# Epoch :   600     Avg. cost =  0.5001
# Epoch :   601     Avg. cost =  0.3831
# Epoch :   602     Avg. cost =  0.7535
# Epoch :   603     Avg. cost =  0.5455
# Epoch :   604     Avg. cost =  0.4660
# Epoch :   605     Avg. cost =  1.2849
# Epoch :   606     Avg. cost =  1.0117
# Epoch :   607     Avg. cost =  0.9877
# Epoch :   608     Avg. cost =  0.8251
# Epoch :   609     Avg. cost =  0.7617
#
# =======================================================================================
# 000:00:25
# =======================================================================================
#
# Epoch :   610     Avg. cost =  0.9077
# Epoch :   611     Avg. cost =  0.8602
# Epoch :   612     Avg. cost =  0.5261
# Epoch :   613     Avg. cost =  0.7772
# Epoch :   614     Avg. cost =  0.7885
# Epoch :   615     Avg. cost =  1.0573
# Epoch :   616     Avg. cost =  0.5924
# Epoch :   617     Avg. cost =  1.1039
# Epoch :   618     Avg. cost =  0.6305
# Epoch :   619     Avg. cost =  0.8911
#
# =======================================================================================
# 000:00:26
# =======================================================================================
#
# Epoch :   620     Avg. cost =  0.6258
# Epoch :   621     Avg. cost =  0.7414
# Epoch :   622     Avg. cost =  0.8171
# Epoch :   623     Avg. cost =  0.6989
# Epoch :   624     Avg. cost =  0.5048
# Epoch :   625     Avg. cost =  0.8295
# Epoch :   626     Avg. cost =  1.0726
# Epoch :   627     Avg. cost =  0.4747
# Epoch :   628     Avg. cost =  1.1518
# Epoch :   629     Avg. cost =  0.5544
#
# =======================================================================================
# 000:00:26
# =======================================================================================
#
# Epoch :   630     Avg. cost =  0.9336
# Epoch :   631     Avg. cost =  0.7625
# Epoch :   632     Avg. cost =  1.0966
# Epoch :   633     Avg. cost =  0.5361
# Epoch :   634     Avg. cost =  0.5584
# Epoch :   635     Avg. cost =  0.3810
# Epoch :   636     Avg. cost =  0.5523
# Epoch :   637     Avg. cost =  0.3100
# Epoch :   638     Avg. cost =  0.3423
# Epoch :   639     Avg. cost =  0.8561
#
# =======================================================================================
# 000:00:26
# =======================================================================================
#
# Epoch :   640     Avg. cost =  0.7895
# Epoch :   641     Avg. cost =  0.8891
# Epoch :   642     Avg. cost =  1.0059
# Epoch :   643     Avg. cost =  0.8265
# Epoch :   644     Avg. cost =  0.6999
# Epoch :   645     Avg. cost =  1.0645
# Epoch :   646     Avg. cost =  0.6660
# Epoch :   647     Avg. cost =  0.6377
# Epoch :   648     Avg. cost =  0.5573
# Epoch :   649     Avg. cost =  0.4768
#
# =======================================================================================
# 000:00:27
# =======================================================================================
#
# Epoch :   650     Avg. cost =  0.9908
# Epoch :   651     Avg. cost =  0.4828
# Epoch :   652     Avg. cost =  0.8023
# Epoch :   653     Avg. cost =  1.1039
# Epoch :   654     Avg. cost =  0.5531
# Epoch :   655     Avg. cost =  0.8429
# Epoch :   656     Avg. cost =  0.5390
# Epoch :   657     Avg. cost =  0.6210
# Epoch :   658     Avg. cost =  0.3801
# Epoch :   659     Avg. cost =  0.5317
#
# =======================================================================================
# 000:00:27
# =======================================================================================
#
# Epoch :   660     Avg. cost =  0.3277
# Epoch :   661     Avg. cost =  0.4576
# Epoch :   662     Avg. cost =  0.9673
# Epoch :   663     Avg. cost =  0.3368
# Epoch :   664     Avg. cost =  0.8901
# Epoch :   665     Avg. cost =  0.6308
# Epoch :   666     Avg. cost =  0.9365
# Epoch :   667     Avg. cost =  0.7349
# Epoch :   668     Avg. cost =  1.0591
# Epoch :   669     Avg. cost =  1.0972
#
# =======================================================================================
# 000:00:28
# =======================================================================================
#
# Epoch :   670     Avg. cost =  0.9092
# Epoch :   671     Avg. cost =  0.7704
# Epoch :   672     Avg. cost =  0.5820
# Epoch :   673     Avg. cost =  0.5158
# Epoch :   674     Avg. cost =  0.5732
# Epoch :   675     Avg. cost =  0.4140
# Epoch :   676     Avg. cost =  1.2859
# Epoch :   677     Avg. cost =  0.6334
# Epoch :   678     Avg. cost =  0.5149
# Epoch :   679     Avg. cost =  0.6543
#
# =======================================================================================
# 000:00:28
# =======================================================================================
#
# Epoch :   680     Avg. cost =  0.6219
# Epoch :   681     Avg. cost =  0.8385
# Epoch :   682     Avg. cost =  0.4348
# Epoch :   683     Avg. cost =  0.8402
# Epoch :   684     Avg. cost =  0.8487
# Epoch :   685     Avg. cost =  0.4261
# Epoch :   686     Avg. cost =  0.6578
# Epoch :   687     Avg. cost =  0.4719
# Epoch :   688     Avg. cost =  0.9091
# Epoch :   689     Avg. cost =  1.1791
#
# =======================================================================================
# 000:00:28
# =======================================================================================
#
# Epoch :   690     Avg. cost =  0.4897
# Epoch :   691     Avg. cost =  0.5786
# Epoch :   692     Avg. cost =  0.7549
# Epoch :   693     Avg. cost =  0.4076
# Epoch :   694     Avg. cost =  0.5200
# Epoch :   695     Avg. cost =  0.9019
# Epoch :   696     Avg. cost =  0.3693
# Epoch :   697     Avg. cost =  0.8683
# Epoch :   698     Avg. cost =  0.8191
# Epoch :   699     Avg. cost =  0.3416
#
# =======================================================================================
# 000:00:29
# =======================================================================================
#
# Epoch :   700     Avg. cost =  0.8196
# Epoch :   701     Avg. cost =  0.5572
# Epoch :   702     Avg. cost =  1.1172
# Epoch :   703     Avg. cost =  0.5917
# Epoch :   704     Avg. cost =  0.3950
# Epoch :   705     Avg. cost =  0.6825
# Epoch :   706     Avg. cost =  0.7958
# Epoch :   707     Avg. cost =  0.6197
# Epoch :   708     Avg. cost =  0.7132
# Epoch :   709     Avg. cost =  0.5383
#
# =======================================================================================
# 000:00:29
# =======================================================================================
#
# Epoch :   710     Avg. cost =  0.7871
# Epoch :   711     Avg. cost =  1.0105
# Epoch :   712     Avg. cost =  0.7308
# Epoch :   713     Avg. cost =  0.8709
# Epoch :   714     Avg. cost =  0.8971
# Epoch :   715     Avg. cost =  0.6197
# Epoch :   716     Avg. cost =  0.5488
# Epoch :   717     Avg. cost =  0.4411
# Epoch :   718     Avg. cost =  1.3225
# Epoch :   719     Avg. cost =  1.1287
#
# =======================================================================================
# 000:00:29
# =======================================================================================
#
# Epoch :   720     Avg. cost =  0.7628
# Epoch :   721     Avg. cost =  0.7177
# Epoch :   722     Avg. cost =  0.7551
# Epoch :   723     Avg. cost =  0.9370
# Epoch :   724     Avg. cost =  0.3272
# Epoch :   725     Avg. cost =  0.6902
# Epoch :   726     Avg. cost =  0.3618
# Epoch :   727     Avg. cost =  0.4671
# Epoch :   728     Avg. cost =  0.7359
# Epoch :   729     Avg. cost =  0.3994
#
# =======================================================================================
# 000:00:30
# =======================================================================================
#
# Epoch :   730     Avg. cost =  1.1551
# Epoch :   731     Avg. cost =  0.7462
# Epoch :   732     Avg. cost =  0.8301
# Epoch :   733     Avg. cost =  0.4678
# Epoch :   734     Avg. cost =  0.6361
# Epoch :   735     Avg. cost =  0.4349
# Epoch :   736     Avg. cost =  0.6306
# Epoch :   737     Avg. cost =  0.6823
# Epoch :   738     Avg. cost =  0.6346
# Epoch :   739     Avg. cost =  0.5833
#
# =======================================================================================
# 000:00:30
# =======================================================================================
#
# Epoch :   740     Avg. cost =  0.8683
# Epoch :   741     Avg. cost =  0.5077
# Epoch :   742     Avg. cost =  0.9682
# Epoch :   743     Avg. cost =  0.8033
# Epoch :   744     Avg. cost =  0.9601
# Epoch :   745     Avg. cost =  0.6725
# Epoch :   746     Avg. cost =  0.6389
# Epoch :   747     Avg. cost =  0.6202
# Epoch :   748     Avg. cost =  0.7805
# Epoch :   749     Avg. cost =  0.6085
#
# =======================================================================================
# 000:00:31
# =======================================================================================
#
# Epoch :   750     Avg. cost =  0.7766
# Epoch :   751     Avg. cost =  0.9337
# Epoch :   752     Avg. cost =  0.7133
# Epoch :   753     Avg. cost =  0.7262
# Epoch :   754     Avg. cost =  0.7554
# Epoch :   755     Avg. cost =  0.5721
# Epoch :   756     Avg. cost =  0.8163
# Epoch :   757     Avg. cost =  1.1546
# Epoch :   758     Avg. cost =  0.6525
# Epoch :   759     Avg. cost =  0.5434
#
# =======================================================================================
# 000:00:31
# =======================================================================================
#
# Epoch :   760     Avg. cost =  0.9323
# Epoch :   761     Avg. cost =  0.6426
# Epoch :   762     Avg. cost =  0.8559
# Epoch :   763     Avg. cost =  0.9565
# Epoch :   764     Avg. cost =  0.7034
# Epoch :   765     Avg. cost =  0.7616
# Epoch :   766     Avg. cost =  0.6273
# Epoch :   767     Avg. cost =  0.8487
# Epoch :   768     Avg. cost =  0.5067
# Epoch :   769     Avg. cost =  0.7356
#
# =======================================================================================
# 000:00:31
# =======================================================================================
#
# Epoch :   770     Avg. cost =  0.3814
# Epoch :   771     Avg. cost =  0.6830
# Epoch :   772     Avg. cost =  0.7776
# Epoch :   773     Avg. cost =  0.4484
# Epoch :   774     Avg. cost =  0.9158
# Epoch :   775     Avg. cost =  0.6196
# Epoch :   776     Avg. cost =  0.4820
# Epoch :   777     Avg. cost =  0.7358
# Epoch :   778     Avg. cost =  0.8048
# Epoch :   779     Avg. cost =  0.7831
#
# =======================================================================================
# 000:00:32
# =======================================================================================
#
# Epoch :   780     Avg. cost =  0.6434
# Epoch :   781     Avg. cost =  0.7540
# Epoch :   782     Avg. cost =  0.6657
# Epoch :   783     Avg. cost =  0.5571
# Epoch :   784     Avg. cost =  0.4722
# Epoch :   785     Avg. cost =  0.5677
# Epoch :   786     Avg. cost =  0.8412
# Epoch :   787     Avg. cost =  0.9022
# Epoch :   788     Avg. cost =  0.4486
# Epoch :   789     Avg. cost =  1.0308
#
# =======================================================================================
# 000:00:32
# =======================================================================================
#
# Epoch :   790     Avg. cost =  1.0311
# Epoch :   791     Avg. cost =  0.7711
# Epoch :   792     Avg. cost =  0.7632
# Epoch :   793     Avg. cost =  0.9040
# Epoch :   794     Avg. cost =  0.6360
# Epoch :   795     Avg. cost =  0.4940
# Epoch :   796     Avg. cost =  0.6334
# Epoch :   797     Avg. cost =  0.9367
# Epoch :   798     Avg. cost =  0.5303
# Epoch :   799     Avg. cost =  0.7233
#
# =======================================================================================
# 000:00:32
# =======================================================================================
#
# Epoch :   800     Avg. cost =  0.9100
# Epoch :   801     Avg. cost =  0.6623
# Epoch :   802     Avg. cost =  0.5343
# Epoch :   803     Avg. cost =  1.0528
# Epoch :   804     Avg. cost =  0.8341
# Epoch :   805     Avg. cost =  0.6911
# Epoch :   806     Avg. cost =  0.7370
# Epoch :   807     Avg. cost =  0.5977
# Epoch :   808     Avg. cost =  0.7903
# Epoch :   809     Avg. cost =  0.6351
#
# =======================================================================================
# 000:00:33
# =======================================================================================
#
# Epoch :   810     Avg. cost =  0.6586
# Epoch :   811     Avg. cost =  0.6273
# Epoch :   812     Avg. cost =  0.5210
# Epoch :   813     Avg. cost =  1.1931
# Epoch :   814     Avg. cost =  0.6392
# Epoch :   815     Avg. cost =  0.8109
# Epoch :   816     Avg. cost =  0.4659
# Epoch :   817     Avg. cost =  0.7738
# Epoch :   818     Avg. cost =  0.2864
# Epoch :   819     Avg. cost =  0.6747
#
# =======================================================================================
# 000:00:33
# =======================================================================================
#
# Epoch :   820     Avg. cost =  0.7336
# Epoch :   821     Avg. cost =  0.9654
# Epoch :   822     Avg. cost =  0.7747
# Epoch :   823     Avg. cost =  0.8683
# Epoch :   824     Avg. cost =  0.5769
# Epoch :   825     Avg. cost =  0.5372
# Epoch :   826     Avg. cost =  0.8755
# Epoch :   827     Avg. cost =  0.7299
# Epoch :   828     Avg. cost =  0.8607
# Epoch :   829     Avg. cost =  0.8708
#
# =======================================================================================
# 000:00:34
# =======================================================================================
#
# Epoch :   830     Avg. cost =  0.9006
# Epoch :   831     Avg. cost =  0.5213
# Epoch :   832     Avg. cost =  0.5921
# Epoch :   833     Avg. cost =  0.7299
# Epoch :   834     Avg. cost =  1.0491
# Epoch :   835     Avg. cost =  1.0679
# Epoch :   836     Avg. cost =  0.8609
# Epoch :   837     Avg. cost =  0.7206
# Epoch :   838     Avg. cost =  0.7494
# Epoch :   839     Avg. cost =  0.6978
#
# =======================================================================================
# 000:00:34
# =======================================================================================
#
# Epoch :   840     Avg. cost =  0.7386
# Epoch :   841     Avg. cost =  0.8034
# Epoch :   842     Avg. cost =  0.8930
# Epoch :   843     Avg. cost =  0.7976
# Epoch :   844     Avg. cost =  0.6954
# Epoch :   845     Avg. cost =  0.7258
# Epoch :   846     Avg. cost =  0.6048
# Epoch :   847     Avg. cost =  0.7399
# ...
# n:  32     label_input:  [0]     label_output:  [8]
# n:  33     label_input:  [0]     label_output:  [0]
# n:  34     label_input:  [0]     label_output:  [0]
# n:  35     label_input:  [0]     label_output:  [0]
# n:  36     label_input:  [0]     label_output:  [0]
# n:  37     label_input:  [0]     label_output:  [0]
# n:  38     label_input:  [0]     label_output:  [0]
# n:  39     label_input:  [0]     label_output:  [0]
# n:  40     label_input:  [0]     label_output:  [0]
# n:  41     label_input:  [0]     label_output:  [0]
# n:  42     label_input:  [0]     label_output:  [0]
# n:  43     label_input:  [0]     label_output:  [1]
# n:  44     label_input:  [0]     label_output:  [8]
# n:  45     label_input:  [0]     label_output:  [0]
# n:  46     label_input:  [0]     label_output:  [0]
# n:  47     label_input:  [0]     label_output:  [8]
# n:  48     label_input:  [0]     label_output:  [0]
# n:  49     label_input:  [0]     label_output:  [8]
# n:  50     label_input:  [0]     label_output:  [0]
# n:  51     label_input:  [0]     label_output:  [0]
# n:  52     label_input:  [0]     label_output:  [0]
# n:  53     label_input:  [4]     label_output:  [4]
# n:  54     label_input:  [4]     label_output:  [4]
# n:  55     label_input:  [4]     label_output:  [4]
# n:  56     label_input:  [4]     label_output:  [3]
# n:  57     label_input:  [4]     label_output:  [4]
# n:  58     label_input:  [4]     label_output:  [2]
# n:  59     label_input:  [4]     label_output:  [4]
# n:  60     label_input:  [4]     label_output:  [4]
# n:  61     label_input:  [4]     label_output:  [4]
# n:  62     label_input:  [4]     label_output:  [4]
# n:  63     label_input:  [4]     label_output:  [4]
# n:  64     label_input:  [4]     label_output:  [4]
# n:  65     label_input:  [4]     label_output:  [4]
# n:  66     label_input:  [4]     label_output:  [3]
# n:  67     label_input:  [4]     label_output:  [4]
# n:  68     label_input:  [4]     label_output:  [4]
# n:  69     label_input:  [4]     label_output:  [4]
# n:  70     label_input:  [4]     label_output:  [4]
# n:  71     label_input:  [4]     label_output:  [4]
# n:  72     label_input:  [4]     label_output:  [4]
# n:  73     label_input:  [4]     label_output:  [4]
# n:  74     label_input:  [4]     label_output:  [4]
# n:  75     label_input:  [4]     label_output:  [4]
# n:  76     label_input:  [4]     label_output:  [4]
# n:  77     label_input:  [4]     label_output:  [4]
# n:  78     label_input:  [4]     label_output:  [4]
# n:  79     label_input:  [4]     label_output:  [8]
# n:  80     label_input:  [4]     label_output:  [3]
# n:  81     label_input:  [4]     label_output:  [4]
# n:  82     label_input:  [4]     label_output:  [4]
# n:  83     label_input:  [4]     label_output:  [4]
# n:  84     label_input:  [4]     label_output:  [8]
# n:  85     label_input:  [4]     label_output:  [8]
# n:  86     label_input:  [4]     label_output:  [4]
# n:  87     label_input:  [4]     label_output:  [4]
# n:  88     label_input:  [4]     label_output:  [4]
# n:  89     label_input:  [4]     label_output:  [4]
# n:  90     label_input:  [4]     label_output:  [4]
# n:  91     label_input:  [4]     label_output:  [4]
# n:  92     label_input:  [4]     label_output:  [4]
# n:  93     label_input:  [4]     label_output:  [4]
# n:  94     label_input:  [4]     label_output:  [4]
# n:  95     label_input:  [4]     label_output:  [4]
# n:  96     label_input:  [4]     label_output:  [4]
# n:  97     label_input:  [4]     label_output:  [4]
# n:  98     label_input:  [4]     label_output:  [4]
# n:  99     label_input:  [4]     label_output:  [4]
# n:  100     label_input:  [4]     label_output:  [4]
# n:  101     label_input:  [4]     label_output:  [4]
# n:  102     label_input:  [4]     label_output:  [4]
# n:  103     label_input:  [4]     label_output:  [4]
# n:  104     label_input:  [4]     label_output:  [4]
# n:  105     label_input:  [3]     label_output:  [3]
# n:  106     label_input:  [3]     label_output:  [5]
# n:  107     label_input:  [3]     label_output:  [3]
# n:  108     label_input:  [3]     label_output:  [3]
# n:  109     label_input:  [3]     label_output:  [3]
# n:  110     label_input:  [3]     label_output:  [4]
# n:  111     label_input:  [3]     label_output:  [3]
# n:  112     label_input:  [3]     label_output:  [3]
# n:  113     label_input:  [3]     label_output:  [3]
# n:  114     label_input:  [3]     label_output:  [3]
# n:  115     label_input:  [3]     label_output:  [3]
# n:  116     label_input:  [3]     label_output:  [4]
# n:  117     label_input:  [3]     label_output:  [4]
# n:  118     label_input:  [3]     label_output:  [3]
# n:  119     label_input:  [3]     label_output:  [3]
# n:  120     label_input:  [3]     label_output:  [3]
# n:  121     label_input:  [3]     label_output:  [3]
# n:  122     label_input:  [3]     label_output:  [4]
# n:  123     label_input:  [3]     label_output:  [3]
# n:  124     label_input:  [3]     label_output:  [3]
# n:  125     label_input:  [3]     label_output:  [8]
# n:  126     label_input:  [3]     label_output:  [3]
# n:  127     label_input:  [3]     label_output:  [3]
# n:  128     label_input:  [3]     label_output:  [3]
# n:  129     label_input:  [3]     label_output:  [3]
# n:  130     label_input:  [3]     label_output:  [3]
# n:  131     label_input:  [3]     label_output:  [3]
# n:  132     label_input:  [3]     label_output:  [3]
# n:  133     label_input:  [3]     label_output:  [8]
# n:  134     label_input:  [2]     label_output:  [3]
# n:  135     label_input:  [2]     label_output:  [4]
# n:  136     label_input:  [2]     label_output:  [3]
# n:  137     label_input:  [2]     label_output:  [3]
# n:  138     label_input:  [2]     label_output:  [3]
# n:  139     label_input:  [2]     label_output:  [2]
# n:  140     label_input:  [2]     label_output:  [2]
# n:  141     label_input:  [2]     label_output:  [7]
# n:  142     label_input:  [2]     label_output:  [2]
# n:  143     label_input:  [2]     label_output:  [2]
# n:  144     label_input:  [2]     label_output:  [3]
# n:  145     label_input:  [2]     label_output:  [2]
# n:  146     label_input:  [2]     label_output:  [3]
# n:  147     label_input:  [2]     label_output:  [2]
# n:  148     label_input:  [2]     label_output:  [3]
# n:  149     label_input:  [2]     label_output:  [2]
# n:  150     label_input:  [2]     label_output:  [4]
# n:  151     label_input:  [2]     label_output:  [3]
# n:  152     label_input:  [8]     label_output:  [8]
# n:  153     label_input:  [8]     label_output:  [8]
# n:  154     label_input:  [8]     label_output:  [0]
# n:  155     label_input:  [8]     label_output:  [8]
# n:  156     label_input:  [8]     label_output:  [8]
# n:  157     label_input:  [8]     label_output:  [8]
# n:  158     label_input:  [8]     label_output:  [8]
# n:  159     label_input:  [8]     label_output:  [8]
# n:  160     label_input:  [8]     label_output:  [8]
# n:  161     label_input:  [8]     label_output:  [0]
# n:  162     label_input:  [8]     label_output:  [8]
# n:  163     label_input:  [8]     label_output:  [0]
# n:  164     label_input:  [8]     label_output:  [0]
# n:  165     label_input:  [8]     label_output:  [8]
# n:  166     label_input:  [8]     label_output:  [0]
# n:  167     label_input:  [8]     label_output:  [8]
# n:  168     label_input:  [8]     label_output:  [8]
# n:  169     label_input:  [8]     label_output:  [0]
# n:  170     label_input:  [8]     label_output:  [8]
# n:  171     label_input:  [8]     label_output:  [8]
# n:  172     label_input:  [8]     label_output:  [8]
# n:  173     label_input:  [8]     label_output:  [8]
# n:  174     label_input:  [8]     label_output:  [8]
# n:  175     label_input:  [8]     label_output:  [8]
# n:  176     label_input:  [8]     label_output:  [8]
# n:  177     label_input:  [8]     label_output:  [8]
# n:  178     label_input:  [8]     label_output:  [8]
# n:  179     label_input:  [8]     label_output:  [8]
# n:  180     label_input:  [8]     label_output:  [8]
# n:  181     label_input:  [8]     label_output:  [8]
# n:  182     label_input:  [8]     label_output:  [8]
# n:  183     label_input:  [8]     label_output:  [8]
# n:  184     label_input:  [8]     label_output:  [8]
# n:  185     label_input:  [8]     label_output:  [0]
# n:  186     label_input:  [8]     label_output:  [8]
# n:  187     label_input:  [8]     label_output:  [8]
# n:  188     label_input:  [8]     label_output:  [8]
# n:  189     label_input:  [8]     label_output:  [8]
# n:  190     label_input:  [8]     label_output:  [8]
# n:  191     label_input:  [8]     label_output:  [8]
# n:  192     label_input:  [8]     label_output:  [0]
# n:  193     label_input:  [8]     label_output:  [8]
# n:  194     label_input:  [8]     label_output:  [0]
# n:  195     label_input:  [8]     label_output:  [8]
# n:  196     label_input:  [8]     label_output:  [8]
# n:  197     label_input:  [8]     label_output:  [8]
# n:  198     label_input:  [8]     label_output:  [8]
# n:  199     label_input:  [8]     label_output:  [8]
# n:  200     label_input:  [8]     label_output:  [8]
# n:  201     label_input:  [8]     label_output:  [8]
# n:  202     label_input:  [8]     label_output:  [8]
# n:  203     label_input:  [8]     label_output:  [8]
# n:  204     label_input:  [8]     label_output:  [8]
# n:  205     label_input:  [8]     label_output:  [8]
# n:  206     label_input:  [8]     label_output:  [8]
# n:  207     label_input:  [8]     label_output:  [8]
# n:  208     label_input:  [8]     label_output:  [4]
# n:  209     label_input:  [8]     label_output:  [8]
# n:  210     label_input:  [8]     label_output:  [8]
# n:  211     label_input:  [8]     label_output:  [0]
# n:  212     label_input:  [8]     label_output:  [8]
# n:  213     label_input:  [8]     label_output:  [8]
# n:  214     label_input:  [8]     label_output:  [0]
# n:  215     label_input:  [8]     label_output:  [1]
# n:  216     label_input:  [8]     label_output:  [4]
# n:  217     label_input:  [8]     label_output:  [8]
# n:  218     label_input:  [8]     label_output:  [8]
# n:  219     label_input:  [8]     label_output:  [8]
# n:  220     label_input:  [8]     label_output:  [8]
# n:  221     label_input:  [8]     label_output:  [8]
# n:  222     label_input:  [8]     label_output:  [8]
# n:  223     label_input:  [8]     label_output:  [8]
# n:  224     label_input:  [8]     label_output:  [8]
# n:  225     label_input:  [8]     label_output:  [8]
# n:  226     label_input:  [8]     label_output:  [8]
# n:  227     label_input:  [8]     label_output:  [8]
# n:  228     label_input:  [8]     label_output:  [8]
# n:  229     label_input:  [8]     label_output:  [8]
# n:  230     label_input:  [8]     label_output:  [8]
# n:  231     label_input:  [8]     label_output:  [8]
# n:  232     label_input:  [8]     label_output:  [8]
# n:  233     label_input:  [8]     label_output:  [8]
# n:  234     label_input:  [8]     label_output:  [8]
# n:  235     label_input:  [8]     label_output:  [0]
# n:  236     label_input:  [7]     label_output:  [7]
# n:  237     label_input:  [7]     label_output:  [7]
# n:  238     label_input:  [7]     label_output:  [7]
# n:  239     label_input:  [7]     label_output:  [7]
# n:  240     label_input:  [7]     label_output:  [7]
# n:  241     label_input:  [7]     label_output:  [7]
# n:  242     label_input:  [7]     label_output:  [7]
# n:  243     label_input:  [7]     label_output:  [7]
# n:  244     label_input:  [7]     label_output:  [7]
# n:  245     label_input:  [7]     label_output:  [7]
# n:  246     label_input:  [7]     label_output:  [7]
# n:  247     label_input:  [7]     label_output:  [7]
# n:  248     label_input:  [7]     label_output:  [7]
# n:  249     label_input:  [7]     label_output:  [7]
# n:  250     label_input:  [7]     label_output:  [7]
# n:  251     label_input:  [7]     label_output:  [7]
# n:  252     label_input:  [7]     label_output:  [7]
# n:  253     label_input:  [7]     label_output:  [7]
# n:  254     label_input:  [7]     label_output:  [7]
# n:  255     label_input:  [7]     label_output:  [7]
# n:  256     label_input:  [7]     label_output:  [7]
# n:  257     label_input:  [7]     label_output:  [7]
# n:  258     label_input:  [7]     label_output:  [7]
# n:  259     label_input:  [7]     label_output:  [7]
# n:  260     label_input:  [7]     label_output:  [7]
# n:  261     label_input:  [7]     label_output:  [7]
# n:  262     label_input:  [7]     label_output:  [7]
# n:  263     label_input:  [7]     label_output:  [7]
# n:  264     label_input:  [7]     label_output:  [7]
# n:  265     label_input:  [7]     label_output:  [7]
# n:  266     label_input:  [5]     label_output:  [5]
# n:  267     label_input:  [5]     label_output:  [5]
# n:  268     label_input:  [5]     label_output:  [5]
# n:  269     label_input:  [5]     label_output:  [5]
# n:  270     label_input:  [5]     label_output:  [5]
# n:  271     label_input:  [6]     label_output:  [8]
# n:  272     label_input:  [1]     label_output:  [1]
# n:  273     label_input:  [1]     label_output:  [1]
# n:  274     label_input:  [1]     label_output:  [1]
# n:  275     label_input:  [1]     label_output:  [0]
# n:  276     label_input:  [1]     label_output:  [1]
# n:  277     label_input:  [1]     label_output:  [0]
# n:  278     label_input:  [1]     label_output:  [1]
# n:  279     label_input:  [1]     label_output:  [0]
# n:  280     label_input:  [1]     label_output:  [0]
# n:  281     label_input:  [1]     label_output:  [0]
# n:  282     label_input:  [1]     label_output:  [0]
# n:  283     label_input:  [1]     label_output:  [1]
# n:  284     label_input:  [1]     label_output:  [1]
# n:  285     label_input:  [1]     label_output:  [0]
# n:  286     label_input:  [1]     label_output:  [8]
# n:  287     label_input:  [1]     label_output:  [1]
# n:  288     label_input:  [1]     label_output:  [1]
# n:  289     label_input:  [1]     label_output:  [0]
# n:  290     label_input:  [1]     label_output:  [1]
# n:  291     label_input:  [1]     label_output:  [1]
# n:  292     label_input:  [1]     label_output:  [8]
# n:  293     label_input:  [1]     label_output:  [1]
# n:  294     label_input:  [1]     label_output:  [1]
# n:  295     label_input:  [1]     label_output:  [1]
# n:  296     label_input:  [1]     label_output:  [0]
# n:  297     label_input:  [1]     label_output:  [8]
# n:  298     label_input:  [1]     label_output:  [0]
# n:  299     label_input:  [1]     label_output:  [1]
# n:  300     label_input:  [1]     label_output:  [1]
# n:  301     label_input:  [1]     label_output:  [1]
# n:  302     label_input:  [1]     label_output:  [1]
# n:  303     label_input:  [1]     label_output:  [1]
# n:  304     label_input:  [1]     label_output:  [0]
# n:  305     label_input:  [1]     label_output:  [1]
# n:  306     label_input:  [1]     label_output:  [0]
# n:  307     label_input:  [1]     label_output:  [0]
# n:  308     label_input:  [1]     label_output:  [1]
# n:  309     label_input:  [1]     label_output:  [1]
# n:  310     label_input:  [1]     label_output:  [1]
# n:  311     label_input:  [1]     label_output:  [0]
# n:  312     label_input:  [1]     label_output:  [8]
# n:  313     label_input:  [1]     label_output:  [1]
# n:  314     label_input:  [1]     label_output:  [8]
# n:  315     label_input:  [1]     label_output:  [8]
# n:  316     label_input:  [1]     label_output:  [1]
# n:  317     label_input:  [1]     label_output:  [1]
# n:  318     label_input:  [1]     label_output:  [4]
# n:  319     label_input:  [1]     label_output:  [1]
# n:  320     label_input:  [1]     label_output:  [1]
# n:  321     label_input:  [1]     label_output:  [1]
# n:  322     label_input:  [1]     label_output:  [1]
# n:  323     label_input:  [1]     label_output:  [1]
# n:  324     label_input:  [1]     label_output:  [1]
# n:  325     label_input:  [1]     label_output:  [1]
# n:  326     label_input:  [1]     label_output:  [0]
# n:  327     label_input:  [1]     label_output:  [8]
# n:  328     label_input:  [1]     label_output:  [1]
# n:  329     label_input:  [1]     label_output:  [1]
#
#           TOTAL ACC    :  0.73333
#
#
# =======================================================================================
# 000:00:41
# =======================================================================================
